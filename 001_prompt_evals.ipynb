# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
please solve the following task:

{test_case["task"]}
"""
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_text_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\n```python\nimport re\n\ndef validate_s3_bucket_name(bucket_name: str) -> tuple[bool, str]:\n    \"\"\"\n    Validates an AWS S3 bucket name according to AWS naming rules.\n    \n    AWS S3 Bucket Naming Rules:\n    - Must be between 3 and 63 characters long\n    - Can only contain lowercase letters, numbers, and hyphens\n    - Must start with a lowercase letter or number\n    - Must end with a lowercase letter or number\n    - Cannot contain consecutive hyphens\n    - Cannot be formatted as an IP address (x.x.x.x)\n    \n    Args:\n        bucket_name (str): The bucket name to validate\n        \n    Returns:\n        tuple[bool, str]: (is_valid, error_message)\n            - is_valid: True if bucket name is valid, False otherwise\n            - error_message: Empty string if valid, otherwise descriptive error message\n    \"\"\"\n    \n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False, \"Bucket name must be a string\"\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3:\n        return False, \"Bucket name must be at least 3 characters long\"\n    if len(bucket_name) > 63:\n        return False, \"Bucket name must be at most 63 characters long\"\n    \n    # Check if starts with lowercase letter or number\n    if not bucket_name[0].isalnum() or bucket_name[0].isupper():\n        return False, \"Bucket name must start with a lowercase letter or number\"\n    \n    # Check if ends with lowercase letter or number\n    if not bucket_name[-1].isalnum() or bucket_name[-1].isupper():\n        return False, \"Bucket name must end with a lowercase letter or number\"\n    \n    # Check for valid characters (lowercase letters, numbers, hyphens only)\n    if not re.match(r'^[a-z0-9-]+$', bucket_name):\n        return False, \"Bucket name can only contain lowercase letters, numbers, and hyphens\"\n    \n    # Check for consecutive hyphens\n    if '--' in bucket_name:\n        return False, \"Bucket name cannot contain consecutive hyphens\"\n    \n    # Check if formatted as IP address (x.x.x.x)\n    if re.match(r'^(\\d{1,3}\\.){3}\\d{1,3}$', bucket_name):\n        return False, \"Bucket name cannot be formatted as an IP address\"\n    \n    return True, \"\"\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid bucket names\n        (\"my-bucket\", True),\n        (\"mybucket123\", True),\n        (\"a\" * 63, True),  # Max length\n        (\"abc\", True),  # Min length\n        (\"my-awesome-bucket-2024\", True),\n        \n        # Invalid bucket names\n        (\"My-Bucket\", False),  # Contains uppercase\n        (\"my_bucket\", False),  # Contains underscore\n        (\"my-bucket-\", False),  # Ends with hyphen\n        (\"-my-bucket\", False),  # Starts with hyphen\n        (\"my\", False),  # Too short (2 characters)\n        (\"a\" * 64, False),  # Too long (64 characters)\n        (\"my--bucket\", False),  # Consecutive hyphens\n        (\"192.168.1.1\", False),  # IP address format\n        (\"my bucket\", False),  # Contains space\n        (\"my.bucket\", False),  # Contains dot (not allowed in validation)\n        (\"\", False),  # Empty string\n        (None, False),  # Not a string\n        (\"MyBucket123\", False),  # Mixed case\n    ]\n    \n    print(\"S3 Bucket Name Validation Results:\")\n    print(\"-\" * 70)\n    \n    for bucket_name, expected_valid in test_cases:\n        is_valid, error_msg = validate_s3_bucket_name(bucket_",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS S3 bucket name according to AWS naming rules (3-63 characters, lowercase letters, numbers, hyphens only, must start and end with letter or number)"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object representing an AWS IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListSpecificBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name\"\n    },\n    {\n      \"Sid\": \"ReadObjectsInBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:GetObjectTagging\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-bucket-name/*\"\n    }\n  ]\n}\n```\n\n## Key Components:\n\n| Component | Description |\n|-----------|-------------|\n| **Version** | `2012-10-17` - Required policy language version |\n| **Statement** | Array of permission rules |\n| **Sid** | Statement ID for documentation |\n| **Effect** | `Allow` to grant permissions |\n| **Action** | Specific S3 operations permitted |\n| **Resource** | ARN specifying the bucket and objects |\n\n## Permissions Explained:\n\n**Statement 1 - Bucket-level permissions:**\n- `s3:ListBucket` - List objects in the bucket\n- `s3:GetBucketVersioning` - View versioning configuration\n- `s3:GetBucketLocation` - Get bucket location\n\n**Statement 2 - Object-level permissions:**\n- `s3:GetObject` - Read object contents\n- `s3:GetObjectVersion` - Read specific object versions\n- `s3:GetObjectTagging` - Read object tags\n\n## Usage:\nReplace `my-bucket-name` with your actual S3 bucket name, then attach this policy to an IAM user, role, or group.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket and its objects"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 ARN Regular Expression\n\nHere's a comprehensive regex pattern that matches valid AWS ARN formats for EC2 instances:\n\n## Basic Pattern\n\n```regex\narn:aws:ec2:[a-z0-9\\-]+:[0-9]{12}:instance/i-[a-z0-9]+\n```\n\n## Enhanced Pattern (More Robust)\n\n```regex\n^arn:aws:ec2:[a-z]{2}((-gov|-cn)?)-[a-z]+-\\d{1,2}:\\d{12}:instance/i-[a-z0-9]+$\n```\n\n## Most Comprehensive Pattern\n\n```regex\n^arn:aws(-[a-z]+)?:ec2:[a-z]{2}((-gov|-cn)?)-[a-z]+-\\d{1,2}:\\d{12}:instance/i-[a-z0-9]+$\n```\n\n---\n\n## Pattern Breakdown\n\n| Component | Regex | Explanation |\n|-----------|-------|-------------|\n| **Prefix** | `arn:aws` | Fixed ARN prefix |\n| **Partition** | `(-[a-z]+)?` | Optional (aws, aws-cn, aws-us-gov) |\n| **Service** | `ec2` | Service identifier |\n| **Region** | `[a-z]{2}((-gov\\|-cn)?)-[a-z]+-\\d{1,2}` | Valid AWS region format |\n| **Account ID** | `\\d{12}` | Exactly 12 digits |\n| **Resource Type** | `instance` | EC2 instance resource |\n| **Instance ID** | `i-[a-z0-9]+` | EC2 instance identifier |\n\n---\n\n## Examples\n\n### \u2705 Valid ARNs\n```\narn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\narn:aws:ec2:eu-west-1:999999999999:instance/i-abc123\narn:aws:ec2:ap-southeast-2:000000000000:instance/i-0a1b2c3d4e5f6g7h8\narn:aws-cn:ec2:cn-north-1:123456789012:instance/i-test123\narn:aws-us-gov:ec2:us-gov-west-1:123456789012:instance/i-gov123\n```\n\n### \u274c Invalid ARNs\n```\narn:aws:ec2:invalid-region:123456789012:instance/i-1234567890abcdef0\narn:aws:ec2:us-east-1:12345:instance/i-1234567890abcdef0  (account ID too short)\narn:aws:ec2:us-east-1:123456789012:volume/vol-12345  (not an instance)\narn:aws:s3:::bucket-name  (wrong service)\n```\n\n---\n\n## Implementation Examples\n\n### JavaScript\n```javascript\nconst arnPattern = /^arn:aws(-[a-z]+)?:ec2:[a-z]{2}((-gov|-cn)?)-[a-z]+-\\d{1,2}:\\d{12}:instance\\/i-[a-z0-9]+$/;\n\nconst isValidArn = (arn) => arnPattern.test(arn);\n\nconsole.log(isValidArn(\"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\")); // true\nconsole.log(isValidArn(\"arn:aws:ec2:invalid:123456789012:instance/i-1234567890abcdef0\")); // false\n```\n\n### Python\n```python\nimport re\n\narn_pattern = r\"^arn:aws(-[a-z]+)?:ec2:[a-z]{2}((-gov|-cn)?)-[a-z]+-\\d{1,2}:\\d{12}:instance/i-[a-z0-9]+$\"\n\ndef is_valid_arn(",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS ARN (Amazon Resource Name) formats for EC2 instances"
#     },
#     "score": 10
#   }
# ]
