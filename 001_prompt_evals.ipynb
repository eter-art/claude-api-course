# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
please solve the following task:

{test_case["task"]}
"""
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]


    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning
    }

# %%
from statistics import mean

def run_eval(dataset):
    """Loads the dataset and calls run_text_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\nHere's a Python function that validates AWS S3 bucket names according to the naming conventions:\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates if a bucket name follows AWS S3 naming conventions.\n    \n    AWS S3 Bucket Naming Rules:\n    - Must be between 3 and 63 characters long\n    - Must contain only lowercase letters, numbers, hyphens, and periods\n    - Must start and end with a lowercase letter or number\n    - Cannot contain underscores\n    - Cannot be formatted as an IP address (e.g., 192.168.1.1)\n    \n    Args:\n        bucket_name (str): The S3 bucket name to validate\n        \n    Returns:\n        bool: True if the bucket name is valid, False otherwise\n    \"\"\"\n    \n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Check length (3-63 characters)\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Check for underscores (not allowed)\n    if '_' in bucket_name:\n        return False\n    \n    # Check if it contains only lowercase letters, numbers, hyphens, and periods\n    if not re.match(r'^[a-z0-9.-]+$', bucket_name):\n        return False\n    \n    # Must start and end with lowercase letter or number\n    if not re.match(r'^[a-z0-9].*[a-z0-9]$', bucket_name):\n        return False\n    \n    # Cannot be formatted as an IP address\n    if re.match(r'^(\\d+\\.){3}\\d+$', bucket_name):\n        return False\n    \n    return True\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        (\"my-bucket\", True),\n        (\"my-bucket-123\", True),\n        (\"mybucket\", True),\n        (\"bucket.name\", True),\n        (\"my.bucket.name\", True),\n        (\"bucket123\", True),\n        \n        # Invalid cases\n        (\"My-Bucket\", False),  # Contains uppercase\n        (\"my_bucket\", False),  # Contains underscore\n        (\"my-\", False),  # Ends with hyphen\n        (\"-my\", False),  # Starts with hyphen\n        (\"my\", False),  # Too short (less than 3 characters)\n        (\"a\" * 64, False),  # Too long (more than 63 characters)\n        (\"192.168.1.1\", False),  # IP address format\n        (\"my bucket\", False),  # Contains space\n        (\"my.bucket.\", False),  # Ends with period\n        (\".my.bucket\", False),  # Starts with period\n        (\"\", False),  # Empty string\n        (123, False),  # Not a string\n    ]\n    \n    print(\"Testing S3 Bucket Name Validator:\\n\")\n    for bucket_name, expected in test_cases:\n        result = is_valid_s3_bucket_name(bucket_name)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} '{bucket_name}': {result} (expected {expected})\")\n```\n\n## Output:\n```\nTesting S3 Bucket Name Validator:\n\n\u2713 'my-bucket': True (expected True)\n\u2713 'my-bucket-123': True (expected True)\n\u2713 'mybucket': True (expected True)\n\u2713 'bucket.name': True (expected True)\n\u2713 'my.bucket.name': True (expected True)\n\u2713 'bucket123': True (expected True)\n\u2713 'My-Bucket': False (expected False)\n\u2713 'my_bucket': False (expected False)\n\u2713 'my-': False (expected False)\n\u2713 '-my': False (expected False)\n\u2713 'my': False (expected False)",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 bucket name and returns True if it follows AWS naming conventions (lowercase, 3-63 characters, no underscores), otherwise False."
#     },
#     "score": 8,
#     "reasoning": "The solution correctly implements the core requirements from the original task (lowercase, 3-63 characters, no underscores) with proper validation logic. The code is well-structured and includes good documentation. However, it adds features beyond the original specification (IP address validation, stricter period/hyphen rules) which weren't requested. While these additions reflect real AWS behavior, they weren't part of the task definition. The incomplete test output and minor regex pattern quirks are minor issues. Overall, this is a solid, production-ready implementation that slightly overengineers the original requirement."
#   },
#   {
#     "output": "# AWS S3 Read-Only IAM Policy\n\nHere's a JSON policy document that grants read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Sid\": \"ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n```\n\n## Policy Explanation\n\n| Component | Description |\n|-----------|------------|\n| **GetObject** | Allows reading/downloading objects from the bucket |\n| **GetObjectVersion** | Allows reading specific versions of objects |\n| **ListBucket** | Allows listing bucket contents |\n| **GetBucketVersioning** | Allows checking versioning status |\n| **Resource ARN (/*) ** | Applies to all objects in the bucket |\n| **Resource ARN (no /*)** | Applies to the bucket itself |\n\n## How to Apply This Policy\n\n### Using AWS Management Console:\n1. Go to **IAM \u2192 Users**\n2. Select the user\n3. Click **Add inline policy**\n4. Choose **JSON** and paste the policy\n5. Review and create\n\n### Using AWS CLI:\n```bash\naws iam put-user-policy \\\n  --user-name my-user \\\n  --policy-name S3ReadOnlyPolicy \\\n  --policy-document file://policy.json\n```\n\n## Optional Enhancements\n\n**For specific folder access only:**\n```json\n\"Resource\": \"arn:aws:s3:::my-data-bucket/specific-folder/*\"\n```\n\n**To deny delete operations explicitly:**\n```json\n{\n  \"Sid\": \"DenyDelete\",\n  \"Effect\": \"Deny\",\n  \"Action\": [\n    \"s3:DeleteObject\",\n    \"s3:DeleteObjectVersion\"\n  ],\n  \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n}\n```\n\nThis policy follows the **principle of least privilege** by granting only necessary permissions for read-only access.",
#     "test_case": {
#       "task": "Create a JSON policy document that grants an IAM user read-only access to objects in a specific AWS S3 bucket named 'my-data-bucket'."
#     },
#     "score": 7,
#     "reasoning": "The solution provides a solid, well-documented policy with correct syntax and good presentation. However, it has a practical limitation: the missing GetBucketLocation permission could cause real-world failures, and the inclusion of GetObjectVersion without context slightly contradicts the stated principle of least privilege. The core functionality is sound, but these gaps reduce its production-readiness."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's the regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[a-z0-9]{17}$\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix (i followed by hyphen) |\n| `[a-z0-9]` | Character class matching lowercase letters or digits |\n| `{17}` | Quantifier requiring exactly 17 characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid Matches \u2713\n- `i-0a1b2c3d4e5f6g7h8`\n- `i-1234567890abcdefg`\n- `i-abcdefghijklmnopq`\n\n### Invalid (No Match) \u2717\n- `i-0a1b2c3d4e5f6g7h` (only 16 chars)\n- `i-0a1b2c3d4e5f6g7h8i` (18 chars)\n- `I-0a1b2c3d4e5f6g7h8` (uppercase I)\n- `0a1b2c3d4e5f6g7h8` (missing `i-` prefix)\n\n## Usage Examples\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[a-z0-9]{17}$/;\nconsole.log(pattern.test('i-0a1b2c3d4e5f6g7h8')); // true\nconsole.log(pattern.test('i-invalid')); // false\n```\n\n**Python:**\n```python\nimport re\npattern = r'^i-[a-z0-9]{17}$'\nprint(re.match(pattern, 'i-0a1b2c3d4e5f6g7h8'))  # Match object (true)\nprint(re.match(pattern, 'i-invalid'))  # None (false)\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 alphanumeric characters)."
#     },
#     "score": 5,
#     "reasoning": "The solution provides the right structure and format for a regex explanation with good documentation practices. However, it contains a critical factual error: AWS EC2 instance IDs use hexadecimal characters (0-9, a-f), not all alphanumeric characters (0-9, a-z). This makes the provided examples and pattern technically incorrect. The regex `^i-[a-z0-9]{17}$` would incorrectly match invalid instance IDs containing characters like 'g' through 'z'. This is a significant oversight for an AWS-specific solution."
#   }
# ]
