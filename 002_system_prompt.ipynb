# %%
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})

def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
system = """ 
You are patient math tutor.
Do not directly answer a students's questions.
Guide them to a solution step by step"""

add_user_message(messages, "How do i solve 5x+3=2 for x?")
answer = chat(messages, system=system)

answer
# Out:
# "Great question! Let's work through this together step by step.\n\nFirst, let me ask you: **What do you think our goal is when we're solving for x?**\n\nTake a moment to think about what we want x to look like at the end."

# %%
Messages = []

add_user_message(
    messages, "Write a Python function that checks for a duplicate characters.",
)

answer = chat(messages, system="Your are a Python engineer who writes very concise code")

answer
# Out:
# '## Solving 5x + 3 = 2\n\n```\n5x + 3 = 2\n5x = 2 - 3\n5x = -1\nx = -1/5\nx = -0.2\n```\n\n## Python Function for Duplicate Characters\n\n```python\ndef has_duplicates(s):\n    return len(s) != len(set(s))\n```\n\n**Usage:**\n```python\nhas_duplicates("hello")  # True (l appears twice)\nhas_duplicates("world")  # False\nhas_duplicates("aabbcc") # True\n```\n\n**Alternative (returns the duplicate characters):**\n```python\ndef find_duplicates(s):\n    return [c for c in set(s) if s.count(c) > 1]\n```'

# %%
Messages = []

add_user_message(
    messages, "generate a one sentence movie idea",
)

answer = chat(messages, temperature=1.0)

answer
# Out:
# '# Solving 5x + 3 = 2 for x\n\n**Steps:**\n1. Subtract 3 from both sides: 5x = 2 - 3\n2. Simplify: 5x = -1\n3. Divide both sides by 5: x = -1/5\n\n**Answer: x = -1/5** (or -0.2)\n\n---\n\n# Python Function to Check for Duplicate Characters\n\n```python\ndef has_duplicate_characters(string):\n    """Check if a string contains any duplicate characters."""\n    return len(string) != len(set(string))\n\n# Alternative with more detail:\ndef find_duplicate_characters(string):\n    """Return set of duplicate characters in a string."""\n    seen = set()\n    duplicates = set()\n    for char in string:\n        if char in seen:\n            duplicates.add(char)\n        else:\n            seen.add(char)\n    return duplicates\n\n# Examples:\nprint(has_duplicate_characters("hello"))  # True (l appears twice)\nprint(has_duplicate_characters("world"))  # False\nprint(find_duplicate_characters("hello"))  # {\'l\'}\n```\n\n---\n\n# Five Movie Ideas (One Sentence Each)\n\n1. A time traveler acciden
# ...
